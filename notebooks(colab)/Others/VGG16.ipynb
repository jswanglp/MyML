# %% [markdown]
# # 初始化

# %%
#@markdown - **挂载** 
from google.colab import drive
drive.mount('GoogleDrive')

# %%
# !nvidia-smi

# %% [markdown]
# ### 卸载 GoogleDrive

# %%
cd /content

# %%
#@markdown - **卸载**
# !fusermount -u GoogleDrive

# %% [markdown]
# # 代码区

# %%
#@title VGG16的调用 { display-mode: "both" }
#@markdown 原始的 `repo` 在[这里](https://github.com/machrisaa/tensorflow-vgg)  

#@markdown 训练好的 `vgg16` 模型参数在[这里](https://mega.nz/#!YU1FWJrA!O1ywiCS2IiOlUCtCpI6HTJOMrneN-Qdv3ywQP5poecM)
# 需要的文件包括: vgg16.py, utils.py, synset.txt, vgg16.npy, test_data
# 修改了 utils.py 中 print_prob函数，返回名称和概率
# 修改了vgg16.py 中 __init__ 函数 allow_pickle=True
# 添加了一次识别多张图像并且输出结果的程序
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import tensorflow as tf
import sys,os
import time

# tf.logging.set_verbosity(tf.logging.ERROR)

# %%
#@markdown - **切换工作路径**
file_path = '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16'
os.chdir(file_path)
os.getcwd()
# Out:
# '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16'

# %%
#@markdown - **Import 主函数**
import vgg16,utils

# %%
#@markdown - **获取所有测试图像**
im_path = os.path.join(file_path, 'test_data')
im_list = [os.path.join(im_path, f) for f in os.listdir(im_path)]
im_list
# Out:
# ['/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/sunglass1_.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/sunglass2_.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/pink-woolen-stole.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/stole.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/mototsikl-racer-nitro.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/racer.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/GettyImages.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/castle-march.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Indian-elephant1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/INDIAN_ELEPHANT.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/dowitcher1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/dowitcher2.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Japanese-Chin-MP.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Japanese-Spaniel.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Beagle-On-White-07.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/beagle.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/snowleopard.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/snow-leopard.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/airship1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/rendering_of_aeroscraft_1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/canoe1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Canoeing-2.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/mailbox.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/Mailbox-Black.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/printer1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/printer2.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/violin1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/viola-and-violin.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/cheeseburger1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/cheeseburger2.jpeg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/artichoke1.jpg',
#  '/content/GoogleDrive/My Drive/Colab Notebooks/vgg16/test_data/artichoke2.jpg']

# %%
#@markdown - **识别所有图片，返回类别名称及概率**
NAME, PROB = [], []
with tf.Session() as sess:
    vgg = vgg16.Vgg16()
    with tf.name_scope('Input'):
        image = tf.placeholder(tf.float32, shape=[1, 224, 224, 3], name='input_image')
        vgg.build(image)
    start_time = time.time()
    for im_l in im_list:
        img = utils.load_image(im_l)
        prob = sess.run(vgg.prob, feed_dict={image: img.reshape((1, 224, 224, 3))})
#         print(prob)
        name, p = utils.print_prob(prob.flatten(), './synset.txt')
        NAME.append(name)
        PROB.append(p)
    end_time = time.time()
# Out:
# /content/GoogleDrive/My Drive/Colab Notebooks/vgg16/vgg16.npy
# npy file loaded
# build model started
# build model finished: 1s
# ('Top1: ', 'n04355933 sunglass', 0.54037833)
# ('Top5: ', [('n04355933 sunglass', 0.54037833), ('n04356056 sunglasses, dark glasses, shades', 0.45961663), ("n03692522 loupe, jeweler's loupe", 4.9181235e-06), ('n04251144 snorkel', 3.5378097e-08), ('n03109150 corkscrew, bottle screw', 3.347034e-08)])
# ('Top1: ', 'n04355933 sunglass', 0.6483179)
# ('Top5: ', [('n04355933 sunglass', 0.6483179), ('n04356056 sunglasses, dark glasses, shades', 0.3507741), ("n03692522 loupe, jeweler's loupe", 0.0002693797), ('n03908714 pencil sharpener', 0.000102222286), ('n03929660 pick, plectrum, plectron', 9.411403e-05)])
# ('Top1: ', 'n04325704 stole', 0.38102835)
# ('Top5: ', [('n04325704 stole', 0.38102835), ('n04599235 wool, woolen, woollen', 0.1587852), ('n03980874 poncho', 0.08859702), ('n03045698 cloak', 0.07577534), ("n02669723 academic gown, academic robe, judge's robe", 0.0618281)])
# ('Top1: ', 'n04325704 stole', 0.9372025)
# ('Top5: ', [('n04325704 stole', 0.9372025), ('n04599235 wool, woolen, woollen', 0.031176273), ('n04136333 sarong', 0.00955266), ('n03627232 knot', 0.0035285237), ('n03617480 kimono', 0.001924138)])
# ('Top1: ', 'n03785016 moped', 0.62191707)
# ('Top5: ', [('n03785016 moped', 0.62191707), ('n03791053 motor scooter, scooter', 0.25146946), ('n03208938 disk brake, disc brake', 0.109891355), ('n03127747 crash helmet', 0.015791647), ('n02769748 backpack, back pack, knapsack, packsack, rucksack, haversack', 0.00045520015)])
# ('Top1: ', 'n03127747 crash helmet', 0.8673241)
# ('Top5: ', [('n03127747 crash helmet', 0.8673241), ('n03379051 football helmet', 0.050681956), ('n09835506 ballplayer, baseball player', 0.022922141), ('n04037443 racer, race car, racing car', 0.01971019), ('n03791053 motor scooter, scooter', 0.006041539)])
# ('Top1: ', 'n02980441 castle', 0.6017196)
# ('Top5: ', [('n02980441 castle', 0.6017196), ('n03877845 palace', 0.15821657), ('n03781244 monastery', 0.08564528), ('n03028079 church, church building', 0.026124772), ('n03032252 cinema, movie theater, movie theatre, movie house, picture palace', 0.023214215)])
# ('Top1: ', 'n02980441 castle', 0.7417857)
# ('Top5: ', [('n02980441 castle', 0.7417857), ('n03877845 palace', 0.19960263), ('n03781244 monastery', 0.028856719), ('n03028079 church, church building', 0.0069921766), ('n03733281 maze, labyrinth', 0.0029321867)])
# ('Top1: ', 'n01871265 tusker', 0.47350693)
# ('Top5: ', [('n01871265 tusker', 0.47350693), ('n02504458 African elephant, Loxodonta africana', 0.27845275), ('n02504013 Indian elephant, Elephas maximus', 0.24803066), ('n01704323 triceratops', 1.9503448e-06), ('n02437312 Arabian camel, dromedary, Camelus dromedarius', 1.9304425e-06)])
# ('Top1: ', 'n01871265 tusker', 0.6951079)
# ('Top5: ', [('n01871265 tusker', 0.6951079), ('n02504013 Indian elephant, Elephas maximus', 0.2797343), ('n02504458 African elephant, Loxodonta africana', 0.025153575), ('n02410509 bison', 2.0509885e-06), ('n02408429 water buffalo, water ox, Asiatic buffalo, Bubalus bubalis', 6.041661e-07)])
# ('Top1: ', 'n02033041 dowitcher', 0.99913484)
# ('Top5: ', [('n02033041 dowitcher', 0.99913484), ('n02028035 redshank, Tringa totanus', 0.00047351973), ('n02027492 red-backed sandpiper, dunlin, Erolia alpina', 0.00024272964), ('n02013706 limpkin, Aramus pictus', 0.00012393162), ('n02006656 spoonbill', 1.7762368e-05)])
# ('Top1: ', 'n02033041 dowitcher', 0.99989367)
# ('Top5: ', [('n02033041 dowitcher', 0.99989367), ('n02027492 red-backed sandpiper, dunlin, Erolia alpina', 6.5937704e-05), ('n02028035 redshank, Tringa totanus', 4.004049e-05), ('n02025239 ruddy turnstone, Arenaria interpres', 2.0472632e-07), ('n02013706 limpkin, Aramus pictus', 1.0609277e-07)])
# ('Top1: ', 'n02085782 Japanese spaniel', 0.99022955)
# ('Top5: ', [('n02085782 Japanese spaniel', 0.99022955), ('n02086910 papillon', 0.008678822), ('n02086079 Pekinese, Pekingese, Peke', 0.00071417034), ('n02086240 Shih-Tzu', 0.000202246), ('n02097474 Tibetan terrier, chrysanthemum dog', 7.84815e-05)])
# ('Top1: ', 'n02085782 Japanese spaniel', 0.98781127)
# ('Top5: ', [('n02085782 Japanese spaniel', 0.98781127), ('n02086910 papillon', 0.011416565), ('n02086079 Pekinese, Pekingese, Peke', 0.0003632466), ('n02085620 Chihuahua', 0.00025334768), ('n02112018 Pomeranian', 0.00010474689)])
# ('Top1: ', 'n02088364 beagle', 0.8992446)
# ('Top5: ', [('n02088364 beagle', 0.8992446), ('n02089973 English foxhound', 0.0718206), ('n02089867 Walker hound, Walker foxhound', 0.028015966), ('n02088238 basset, basset hound', 0.0005277533), ('n02088632 bluetick', 0.00029362357)])
# ('Top1: ', 'n02088364 beagle', 0.918844)
# ('Top5: ', [('n02088364 beagle', 0.918844), ('n02089973 English foxhound', 0.030409725), ('n02089867 Walker hound, Walker foxhound', 0.029122397), ('n02088632 bluetick', 0.012202447), ('n02088238 basset, basset hound', 0.009049653)])
# ('Top1: ', 'n02128757 snow leopard, ounce, Panthera uncia', 0.9324051)
# ('Top5: ', [('n02128757 snow leopard, ounce, Panthera uncia', 0.9324051), ('n02128385 leopard, Panthera pardus', 0.04605115), ('n02127052 lynx, catamount', 0.019005703), ('n02130308 cheetah, chetah, Acinonyx jubatus', 0.0017467039), ('n02128925 jaguar, panther, Panthera onca, Felis onca', 0.0006764691)])
# ('Top1: ', 'n02128757 snow leopard, ounce, Panthera uncia', 0.9325632)
# ('Top5: ', [('n02128757 snow leopard, ounce, Panthera uncia', 0.9325632), ('n02128385 leopard, Panthera pardus', 0.054432433), ('n02124075 Egyptian cat', 0.007118999), ('n02127052 lynx, catamount', 0.0026881031), ('n02128925 jaguar, panther, Panthera onca, Felis onca', 0.0011821197)])
# ('Top1: ', 'n02692877 airship, dirigible', 0.9987005)
# ('Top5: ', [('n02692877 airship, dirigible', 0.9987005), ('n02690373 airliner', 0.0004747153), ('n04552348 warplane, military plane', 0.00042023847), ('n04592741 wing', 0.00025622163), ('n03888257 parachute, chute', 4.6767767e-05)])
# ('Top1: ', 'n02692877 airship, dirigible', 0.90853053)
# ('Top5: ', [('n02692877 airship, dirigible', 0.90853053), ('n04552348 warplane, military plane', 0.02892582), ('n04592741 wing', 0.019076854), ('n02690373 airliner', 0.017891588), ('n04266014 space shuttle', 0.011443247)])
# ('Top1: ', 'n02951358 canoe', 0.94530255)
# ('Top5: ', [('n02951358 canoe', 0.94530255), ('n03873416 paddle, boat paddle', 0.054466248), ('n04141327 scabbard', 5.9483966e-05), ('n03658185 letter opener, paper knife, paperknife', 2.3890663e-05), ('n09332890 lakeside, lakeshore', 2.302276e-05)])
# ('Top1: ', 'n02951358 canoe', 0.8490595)
# ('Top5: ', [('n02951358 canoe', 0.8490595), ('n03873416 paddle, boat paddle', 0.14665109), ('n04273569 speedboat', 0.0014033865), ('n02981792 catamaran', 0.00052948785), ('n04483307 trimaran', 0.00050557195)])
# ('Top1: ', 'n03710193 mailbox, letter box', 0.48886096)
# ('Top5: ', [('n03710193 mailbox, letter box', 0.48886096), ('n06794110 street sign', 0.12554665), ('n02950826 cannon', 0.09081745), ('n06874185 traffic light, traffic signal, stoplight', 0.068763055), ('n02747177 ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 0.06128957)])
# ('Top1: ', 'n03710193 mailbox, letter box', 0.8148754)
# ('Top5: ', [('n03710193 mailbox, letter box', 0.8148754), ('n03337140 file, file cabinet, filing cabinet', 0.065036006), ('n03180011 desktop computer', 0.03065586), ('n03691459 loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', 0.012397171), ('n02747177 ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', 0.011566592)])
# ('Top1: ', 'n04004767 printer', 0.9773221)
# ('Top5: ', [('n04004767 printer', 0.9773221), ('n03924679 photocopier', 0.022621168), ('n03976467 Polaroid camera, Polaroid Land camera', 4.8086644e-05), ('n04505470 typewriter keyboard', 2.3384375e-06), ('n04264628 space bar', 1.5808648e-06)])
# ('Top1: ', 'n03793489 mouse, computer mouse', 0.46423873)
# ('Top5: ', [('n03793489 mouse, computer mouse', 0.46423873), ('n04004767 printer', 0.13371056), ('n03777754 modem', 0.10398483), ('n04009552 projector', 0.10387343), ('n03832673 notebook, notebook computer', 0.05397801)])
# ('Top1: ', 'n04536866 violin, fiddle', 0.8639342)
# ('Top5: ', [('n04536866 violin, fiddle', 0.8639342), ('n02992211 cello, violoncello', 0.13475221), ('n02879718 bow', 0.0002723782), ('n03272010 electric guitar', 0.00024537838), ('n04090263 rifle', 0.00024348995)])
# ('Top1: ', 'n04536866 violin, fiddle', 0.95895624)
# ('Top5: ', [('n04536866 violin, fiddle', 0.95895624), ('n02992211 cello, violoncello', 0.041042805), ('n04090263 rifle', 5.786768e-07), ('n02749479 assault rifle, assault gun', 7.394654e-08), ('n03598930 jigsaw puzzle', 5.6504724e-08)])
# ('Top1: ', 'n07697313 cheeseburger', 0.98277515)
# ('Top5: ', [('n07697313 cheeseburger', 0.98277515), ('n07693725 bagel, beigel', 0.013664431), ('n07684084 French loaf', 0.00055104954), ('n07697537 hotdog, hot dog, red hot', 0.0005283027), ('n07875152 potpie', 0.00049054564)])
# ('Top1: ', 'n07697313 cheeseburger', 0.90745574)
# ('Top5: ', [('n07697313 cheeseburger', 0.90745574), ('n07880968 burrito', 0.020212932), ('n07579787 plate', 0.014517124), ('n07693725 bagel, beigel', 0.0075709415), ('n07697537 hotdog, hot dog, red hot', 0.007355124)])
# ('Top1: ', 'n07718747 artichoke, globe artichoke', 0.99855775)
# ('Top5: ', [('n07718747 artichoke, globe artichoke', 0.99855775), ('n07760859 custard apple', 0.0004984439), ('n07714571 head cabbage', 0.00023004036), ('n07753275 pineapple, ananas', 0.00012883927), ('n07742313 Granny Smith', 8.134646e-05)])
# ('Top1: ', 'n07718747 artichoke, globe artichoke', 0.9982108)
# ('Top5: ', [('n07718747 artichoke, globe artichoke', 0.9982108), ('n07760859 custard apple', 0.0017342678), ('n07753275 pineapple, ananas', 2.3213197e-05), ('n07714571 head cabbage', 1.6685655e-05), ('n07730033 cardoon', 1.3267085e-05)])

# %%
#@markdown - **提取所有类别名称，概率**
num = len(im_list)
print('There are {} images in total, recognition time: {:.4f}s.'.format(num, end_time - start_time))
TITLE = [', '.join([name[10:], str(p)]) for name, p in zip(NAME, PROB)]
TITLE
# Out:
# There are 32 images in total, recognition time: 5.9349s.
# ['sunglass, 0.54037833',
#  'sunglass, 0.6483179',
#  'stole, 0.38102835',
#  'stole, 0.9372025',
#  'moped, 0.62191707',
#  'crash helmet, 0.8673241',
#  'castle, 0.6017196',
#  'castle, 0.7417857',
#  'tusker, 0.47350693',
#  'tusker, 0.6951079',
#  'dowitcher, 0.99913484',
#  'dowitcher, 0.99989367',
#  'Japanese spaniel, 0.99022955',
#  'Japanese spaniel, 0.98781127',
#  'beagle, 0.8992446',
#  'beagle, 0.918844',
#  'snow leopard, ounce, Panthera uncia, 0.9324051',
#  'snow leopard, ounce, Panthera uncia, 0.9325632',
#  'airship, dirigible, 0.9987005',
#  'airship, dirigible, 0.90853053',
#  'canoe, 0.94530255',
#  'canoe, 0.8490595',
#  'mailbox, letter box, 0.48886096',
#  'mailbox, letter box, 0.8148754',
#  'printer, 0.9773221',
#  'mouse, computer mouse, 0.46423873',
#  'violin, fiddle, 0.8639342',
#  'violin, fiddle, 0.95895624',
#  'cheeseburger, 0.98277515',
#  'cheeseburger, 0.90745574',
#  'artichoke, globe artichoke, 0.99855775',
#  'artichoke, globe artichoke, 0.9982108']

# %%
#@markdown - **打印所有图片及其所属类别、概率**
cols = 3 # 每行显示的图片数
nrows = num // cols + 1
height = nrows * 5
fig = plt.figure(1, figsize=(15, height))
gs = gridspec.GridSpec(nrows, 3)
for i, im_l in enumerate(im_list):
    row = i // cols
    col = i % cols
    img = utils.load_image(im_l)
    img = img / img.max()
    title = TITLE[i]
    ax = fig.add_subplot(gs[row, col])
    ax.imshow(img)
    ax.set_title(title.capitalize(), fontsize=14)
    ax.set_xticks([]), ax.set_yticks([])

# fig.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
