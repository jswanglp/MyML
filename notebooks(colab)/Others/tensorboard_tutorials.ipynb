# %% [markdown]
# # 初始化

# %%
#@markdown - **挂载** 
from google.colab import drive
drive.mount('GoogleDrive')

# %%
#@markdown - **卸载**
# !fusermount -u GoogleDrive

# %% [markdown]
# # 代码区

# %%
#@title tensorboard 的使用{ display-mode: "both" }
# tensorboard_tutorials
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import time,os

# %%
#@markdown - **读取 cifar-10 训练、测试集数据**
cifar_train = tfds.as_numpy(tfds.load("cifar10", split=tfds.Split.TRAIN, batch_size=-1))
imgs_train, labels_train = cifar_train['image'].reshape(-1, 3072) / 255., cifar_train['label']

cifar_test = tfds.as_numpy(tfds.load("cifar10", split=tfds.Split.TEST, batch_size=-1))
imgs_test, labels_test = cifar_test['image'].reshape(-1, 3072) / 255., cifar_test['label']

# %%
#@markdown - **参数、路径设置**
learning_rate = 5e-4 #@param {type:"number"}
batch_size = 196 #@param {type:"integer"}
num_epochs = 100 #@param {type:"integer"}

event_path = 'GoogleDrive/My Drive/Colab Notebooks/Tensorboard'
checkpoints_path = './Checkpoints'

# %%
#@markdown - **设置网络图**
graph = tf.Graph()
with graph.as_default():

    global_step = tf.Variable(0, name='global_step', trainable=False)
    with tf.name_scope('Input'):
        x = tf.placeholder(tf.float32, shape=[None, 3072], name='input_images')
        x_imgs = tf.reshape(x, shape=[-1, 32, 32, 3], name='images')
        y_p = tf.placeholder(tf.int32, shape=[None, ], name='labels')
        y = tf.one_hot(y_p, depth=10, name='one_hot_labels')
        keep_pro = tf.placeholder(tf.float32)

    with tf.name_scope('Conv_layers'):
        with tf.name_scope('Conv1'):
            w_1 = tf.Variable(tf.truncated_normal([3, 3, 3, 64], stddev=0.1), name='weights_conv1')
            b_1 = tf.Variable(tf.constant(0.1, shape=[64]), name='bias_conv1')
            h_conv1 = tf.nn.relu(tf.nn.conv2d(x_imgs, w_1, strides=[1, 1, 1, 1], padding='SAME') + b_1)
            h_pool1 = tf.nn.max_pool(h_conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

        with tf.name_scope('Conv2'):
            w_2 = tf.Variable(tf.truncated_normal([3, 3, 64, 128], stddev=0.1), name='weights_conv2')
            b_2 = tf.Variable(tf.constant(0.1, shape=[128]), name='bias_conv2')
            h_conv2 = tf.nn.relu(tf.nn.conv2d(h_pool1, w_2, strides=[1, 1, 1, 1], padding='SAME') + b_2)
            h_pool2 = tf.nn.max_pool(h_conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
        
        with tf.name_scope('Conv3'):
            w_3 = tf.Variable(tf.truncated_normal([3, 3, 128, 256], stddev=0.1), name='weights_conv3')
            b_3 = tf.Variable(tf.constant(0.1, shape=[256]), name='bias_conv3')
            h_conv3 = tf.nn.relu(tf.nn.conv2d(h_pool2, w_3, strides=[1, 1, 1, 1], padding='SAME') + b_3)
            h_pool3 = tf.nn.max_pool(h_conv3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    
    with tf.name_scope('Fc_layers'):
        with tf.name_scope('Fc1'):
            h_pool3_fla = tf.layers.flatten(h_pool3)
            num_f = h_pool3_fla.get_shape().as_list()[-1]

            w_fc1 = tf.Variable(tf.truncated_normal([num_f, 512], stddev=0.1), name='weights_fc1')
            b_fc1 = tf.Variable(tf.constant(0.1, shape=[512]), name='bias_fc1')
            h_fc1 = tf.nn.relu(tf.matmul(h_pool3_fla, w_fc1) + b_fc1)
            h_drop1 = tf.nn.dropout(h_fc1, keep_prob=keep_pro, name='Dropout1')

        with tf.name_scope('Fc2'):
            w_fc2 = tf.Variable(tf.truncated_normal([512, 256], stddev=0.1), name='weights_fc2')
            b_fc2 = tf.Variable(tf.constant(0.1, shape=[256]), name='bias_fc2')
            h_fc2 = tf.nn.relu(tf.matmul(h_drop1, w_fc2) + b_fc2)
            h_drop2 = tf.nn.dropout(h_fc2, keep_prob=keep_pro, name='Dropout2')

    with tf.name_scope('Output'):
        w_op = tf.Variable(tf.truncated_normal([256, 10], stddev=0.1), name='weights_op')
        b_op = tf.Variable(tf.constant(0.1, shape=[10]), name='bias_op')
        h_op = tf.matmul(h_drop2, w_op) + b_op
    
    #@markdown - **L2 正则化**
    tf.add_to_collection(tf.GraphKeys.WEIGHTS, w_fc1)
    tf.add_to_collection(tf.GraphKeys.WEIGHTS, w_fc2)
    regularizer = tf.contrib.layers.l2_regularizer(scale=150./50000)
    reg_tem = tf.contrib.layers.apply_regularization(regularizer)

    with tf.name_scope('loss'):
        # entropy_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=h_op))
        entropy_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=h_op) + reg_tem)
    
    with tf.name_scope('accuracy'):
        prediction = tf.cast(tf.equal(tf.arg_max(h_op, 1), tf.argmax(y, 1)), "float")
        accuracy = tf.reduce_mean(prediction)
    
    with tf.name_scope('train'):
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(entropy_loss, global_step=global_step)
    
    #@markdown - **两类 summary**
    tf.summary.image('input_images', x_imgs, max_outputs=3, collections=['train', 'test'])
    tf.summary.histogram('conv1_weights', w_1, collections=['train'])
    tf.summary.histogram('conv1_bias', b_1, collections=['train'])
    tf.summary.scalar('loss', entropy_loss, collections=['train', 'test'])
    tf.summary.scalar('accuracy', accuracy, collections=['train', 'test'])

    summ_train = tf.summary.merge_all('train')
    summ_test = tf.summary.merge_all('test')

# %%
#@markdown - **训练网络**
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())

    summ_train_dir = os.path.join(event_path, 'summaries','train')
    summ_train_Writer = tf.summary.FileWriter(summ_train_dir)
    summ_train_Writer.add_graph(sess.graph)

    summ_test_dir = os.path.join(event_path, 'summaries', 'test')
    summ_test_Writer = tf.summary.FileWriter(summ_test_dir)
    summ_test_Writer.add_graph(sess.graph)

    for num in range(num_epochs):
        imgs_data = np.c_[imgs_train, labels_train]
        np.random.shuffle(imgs_data)
        num_batchs = imgs_train.shape[0] // batch_size
        start = time.time()
        for num_ep in range(num_batchs):
            # start = time.time()
            imgs_batch = imgs_data[num_ep*batch_size:(num_ep+1)*batch_size, :-1]
            labels_batch = imgs_data[num_ep*batch_size:(num_ep+1)*batch_size,-1]
            _, acc, loss, rt, num_step = sess.run([train_op, accuracy, entropy_loss, summ_train, global_step], 
                                                    feed_dict={x: imgs_batch, y_p: labels_batch, keep_pro: 0.5})
        summ_train_Writer.add_summary(rt, global_step=num_step)
        end = time.time()
        acc *= 100
        num_e = str(num + 1)
        print_list = [num_e, loss, acc]
        print("Epoch {0[0]}, train_loss is {0[1]:.4f}, accuracy is {0[2]:.2f}%.".format(print_list))
#         print("Running time is {0:.2f}s.".format(end-start))
        _, acc, loss, rs = sess.run([train_op, accuracy, entropy_loss, summ_test], feed_dict={x: imgs_test,
                                                                                    y_p: labels_test,
                                                                                    keep_pro: 1.})
        summ_test_Writer.add_summary(rs, global_step=num_step)
        acc *= 100
        print_list = [loss, acc]
        print("Test_loss is {0[0]:.4f}, accuracy is {0[1]:.2f}%.\n".format(print_list))
    print('Training completed.')
sess.close()
# Out:
# Epoch 1, train_loss is 13.3449, accuracy is 27.55%.
# Test_loss is 13.1324, accuracy is 38.97%.
#
# Epoch 2, train_loss is 8.2495, accuracy is 41.33%.
# Test_loss is 8.0686, accuracy is 47.52%.
#
# Epoch 3, train_loss is 5.7625, accuracy is 41.33%.
# Test_loss is 5.5188, accuracy is 52.32%.
#
# Epoch 4, train_loss is 3.9094, accuracy is 59.18%.
# Test_loss is 3.9169, accuracy is 58.08%.
#
# Epoch 5, train_loss is 3.0399, accuracy is 55.10%.
# Test_loss is 2.8806, accuracy is 62.68%.
#
# Epoch 6, train_loss is 2.3232, accuracy is 60.71%.
# Test_loss is 2.2236, accuracy is 65.90%.
#
# Epoch 7, train_loss is 1.7366, accuracy is 68.88%.
# Test_loss is 1.8137, accuracy is 66.39%.
#
# Epoch 8, train_loss is 1.5402, accuracy is 65.82%.
# Test_loss is 1.4994, accuracy is 69.58%.
#
# Epoch 9, train_loss is 1.4844, accuracy is 63.78%.
# Test_loss is 1.3046, accuracy is 71.13%.
#
# Epoch 10, train_loss is 1.3289, accuracy is 70.92%.
# Test_loss is 1.2356, accuracy is 69.68%.
#
# Epoch 11, train_loss is 1.0305, accuracy is 75.00%.
# Test_loss is 1.0835, accuracy is 73.39%.
#
# Epoch 12, train_loss is 0.9795, accuracy is 77.04%.
# Test_loss is 1.0466, accuracy is 73.22%.
#
# Epoch 13, train_loss is 0.9552, accuracy is 75.00%.
# Test_loss is 1.0140, accuracy is 74.30%.
#
# Epoch 14, train_loss is 0.8538, accuracy is 79.08%.
# Test_loss is 0.9751, accuracy is 75.02%.
#
# Epoch 15, train_loss is 0.8744, accuracy is 79.08%.
# Test_loss is 1.0333, accuracy is 73.10%.
#
# Epoch 16, train_loss is 0.8131, accuracy is 80.10%.
# Test_loss is 0.9429, accuracy is 75.96%.
#
# Epoch 17, train_loss is 0.7059, accuracy is 83.67%.
# Test_loss is 0.9581, accuracy is 75.27%.
#
# Epoch 18, train_loss is 0.6177, accuracy is 86.22%.
# Test_loss is 0.9800, accuracy is 75.17%.
#
# Epoch 19, train_loss is 0.6812, accuracy is 86.73%.
# Test_loss is 0.9676, accuracy is 75.87%.
#
# Epoch 20, train_loss is 0.6948, accuracy is 84.69%.
# Test_loss is 0.9437, accuracy is 76.64%.
#
# Epoch 21, train_loss is 0.7422, accuracy is 84.18%.
# Test_loss is 0.9646, accuracy is 76.85%.
#
# Epoch 22, train_loss is 0.6693, accuracy is 82.65%.
# Test_loss is 0.9751, accuracy is 76.56%.
#
# Epoch 23, train_loss is 0.6713, accuracy is 87.24%.
# Test_loss is 0.9857, accuracy is 76.75%.
#
# Epoch 24, train_loss is 0.6142, accuracy is 87.76%.
# Test_loss is 0.9837, accuracy is 76.93%.
#
# Epoch 25, train_loss is 0.5821, accuracy is 88.27%.
# Test_loss is 0.9812, accuracy is 76.93%.
#
# Epoch 26, train_loss is 0.6498, accuracy is 84.69%.
# Test_loss is 0.9932, accuracy is 77.05%.
#
# Epoch 27, train_loss is 0.6956, accuracy is 85.20%.
# Test_loss is 1.0121, accuracy is 76.84%.
#
# Epoch 28, train_loss is 0.4878, accuracy is 91.33%.
# Test_loss is 1.0218, accuracy is 76.25%.
#
# Epoch 29, train_loss is 0.5617, accuracy is 88.78%.
# Test_loss is 1.0423, accuracy is 76.59%.
#
# Epoch 30, train_loss is 0.5035, accuracy is 91.33%.
# Test_loss is 1.0191, accuracy is 77.01%.
#
# Epoch 31, train_loss is 0.4594, accuracy is 91.33%.
# Test_loss is 1.0483, accuracy is 77.34%.
#
# Epoch 32, train_loss is 0.5018, accuracy is 92.35%.
# Test_loss is 1.0632, accuracy is 76.93%.
#
# Epoch 33, train_loss is 0.4586, accuracy is 93.88%.
# Test_loss is 1.0614, accuracy is 76.56%.
#
# Epoch 34, train_loss is 0.4743, accuracy is 93.88%.
# Test_loss is 1.0309, accuracy is 77.21%.
#
# Epoch 35, train_loss is 0.5337, accuracy is 91.84%.
# Test_loss is 1.0542, accuracy is 77.68%.
#
# Epoch 36, train_loss is 0.4298, accuracy is 94.90%.
# Test_loss is 1.0398, accuracy is 77.52%.
#
# Epoch 37, train_loss is 0.3295, accuracy is 96.94%.
# Test_loss is 1.0733, accuracy is 77.41%.
#
# Epoch 38, train_loss is 0.4291, accuracy is 92.86%.
# Test_loss is 1.1006, accuracy is 76.57%.
#
# Epoch 39, train_loss is 0.4247, accuracy is 94.90%.
# Test_loss is 1.1273, accuracy is 76.65%.
#
# Epoch 40, train_loss is 0.4706, accuracy is 92.35%.
# Test_loss is 1.0634, accuracy is 77.22%.
#
# Epoch 41, train_loss is 0.3851, accuracy is 95.41%.
# Test_loss is 1.1039, accuracy is 76.62%.
#
# Epoch 42, train_loss is 0.3445, accuracy is 96.94%.
# Test_loss is 1.1079, accuracy is 76.92%.
#
# Epoch 43, train_loss is 0.4159, accuracy is 93.88%.
# Test_loss is 1.1551, accuracy is 76.57%.
#
# Epoch 44, train_loss is 0.3559, accuracy is 95.41%.
# Test_loss is 1.0767, accuracy is 77.44%.
#
# Epoch 45, train_loss is 0.3407, accuracy is 96.94%.
# Test_loss is 1.0955, accuracy is 77.75%.
#
# Epoch 46, train_loss is 0.3755, accuracy is 95.92%.
# Test_loss is 1.0721, accuracy is 77.69%.
#
# Epoch 47, train_loss is 0.3023, accuracy is 97.45%.
# Test_loss is 1.0784, accuracy is 77.42%.
#
# Epoch 48, train_loss is 0.3027, accuracy is 97.45%.
# Test_loss is 1.0820, accuracy is 78.42%.
#
# Epoch 49, train_loss is 0.3391, accuracy is 95.41%.
# Test_loss is 1.1056, accuracy is 77.61%.
#
# Epoch 50, train_loss is 0.3838, accuracy is 94.90%.
# Test_loss is 1.1130, accuracy is 77.37%.
#
# Epoch 51, train_loss is 0.3596, accuracy is 95.41%.
# Test_loss is 1.1477, accuracy is 77.37%.
#
# Epoch 52, train_loss is 0.3269, accuracy is 96.43%.
# Test_loss is 1.1304, accuracy is 77.40%.
#
# Epoch 53, train_loss is 0.3776, accuracy is 94.90%.
# Test_loss is 1.1101, accuracy is 77.71%.
#
# Epoch 54, train_loss is 0.3268, accuracy is 95.92%.
# Test_loss is 1.1043, accuracy is 78.41%.
#
# Epoch 55, train_loss is 0.2863, accuracy is 96.43%.
# Test_loss is 1.0983, accuracy is 78.04%.
#
# Epoch 56, train_loss is 0.3005, accuracy is 96.43%.
# Test_loss is 1.1173, accuracy is 77.88%.
#
# Epoch 57, train_loss is 0.2970, accuracy is 96.94%.
# Test_loss is 1.1155, accuracy is 77.86%.
#
# Epoch 58, train_loss is 0.3279, accuracy is 96.94%.
# Test_loss is 1.1225, accuracy is 77.96%.
#
# Epoch 59, train_loss is 0.2858, accuracy is 96.43%.
# Test_loss is 1.1383, accuracy is 77.38%.
#
# Epoch 60, train_loss is 0.3747, accuracy is 93.88%.
# Test_loss is 1.1353, accuracy is 78.44%.
#
# Epoch 61, train_loss is 0.2906, accuracy is 96.43%.
# Test_loss is 1.1198, accuracy is 78.01%.
#
# Epoch 62, train_loss is 0.2977, accuracy is 96.43%.
# Test_loss is 1.1842, accuracy is 76.96%.
#
# Epoch 63, train_loss is 0.3321, accuracy is 94.39%.
# Test_loss is 1.1056, accuracy is 78.56%.
#
# Epoch 64, train_loss is 0.2469, accuracy is 98.47%.
# Test_loss is 1.1040, accuracy is 78.00%.
#
# Epoch 65, train_loss is 0.3025, accuracy is 94.90%.
# Test_loss is 1.1153, accuracy is 78.43%.
#
# Epoch 66, train_loss is 0.3325, accuracy is 96.43%.
# Test_loss is 1.0813, accuracy is 78.31%.
#
# Epoch 67, train_loss is 0.2518, accuracy is 97.45%.
# Test_loss is 1.1425, accuracy is 78.16%.
#
# Epoch 68, train_loss is 0.2802, accuracy is 97.45%.
# Test_loss is 1.1189, accuracy is 78.30%.
#
# Epoch 69, train_loss is 0.2576, accuracy is 97.96%.
# Test_loss is 1.0801, accuracy is 78.65%.
#
# Epoch 70, train_loss is 0.3146, accuracy is 96.43%.
# Test_loss is 1.1533, accuracy is 77.80%.
#
# Epoch 71, train_loss is 0.2698, accuracy is 98.47%.
# Test_loss is 1.0911, accuracy is 78.49%.
#
# Epoch 72, train_loss is 0.2358, accuracy is 98.98%.
# Test_loss is 1.1450, accuracy is 78.13%.
#
# Epoch 73, train_loss is 0.3005, accuracy is 97.45%.
# Test_loss is 1.0850, accuracy is 78.99%.
#
# Epoch 74, train_loss is 0.2666, accuracy is 97.96%.
# Test_loss is 1.0848, accuracy is 78.96%.
#
# Epoch 75, train_loss is 0.3117, accuracy is 96.43%.
# Test_loss is 1.0840, accuracy is 78.85%.
#
# Epoch 76, train_loss is 0.3075, accuracy is 96.43%.
# Test_loss is 1.0808, accuracy is 78.44%.
#
# Epoch 77, train_loss is 0.3268, accuracy is 94.90%.
# Test_loss is 1.1520, accuracy is 77.89%.
#
# Epoch 78, train_loss is 0.2662, accuracy is 97.45%.
# Test_loss is 1.0726, accuracy is 78.90%.
#
# Epoch 79, train_loss is 0.2325, accuracy is 98.47%.
# Test_loss is 1.0570, accuracy is 79.23%.
#
# Epoch 80, train_loss is 0.2694, accuracy is 97.45%.
# Test_loss is 1.1158, accuracy is 78.41%.
#
# Epoch 81, train_loss is 0.2384, accuracy is 96.94%.
# Test_loss is 1.1453, accuracy is 78.11%.
#
# Epoch 82, train_loss is 0.2691, accuracy is 96.43%.
# Test_loss is 1.0850, accuracy is 79.13%.
#
# Epoch 83, train_loss is 0.3059, accuracy is 96.94%.
# Test_loss is 1.0912, accuracy is 78.94%.
#
# Epoch 84, train_loss is 0.3087, accuracy is 94.90%.
# Test_loss is 1.1158, accuracy is 78.65%.
#
# Epoch 85, train_loss is 0.2226, accuracy is 97.96%.
# Test_loss is 1.0906, accuracy is 79.42%.
#
# Epoch 86, train_loss is 0.2380, accuracy is 98.98%.
# Test_loss is 1.0946, accuracy is 78.89%.
#
# Epoch 87, train_loss is 0.2770, accuracy is 97.45%.
# Test_loss is 1.0956, accuracy is 79.31%.
#
# Epoch 88, train_loss is 0.2693, accuracy is 97.45%.
# Test_loss is 1.1097, accuracy is 78.75%.
#
# Epoch 89, train_loss is 0.2292, accuracy is 97.96%.
# Test_loss is 1.0634, accuracy is 79.37%.
#
# Epoch 90, train_loss is 0.2037, accuracy is 99.49%.
# Test_loss is 1.0690, accuracy is 79.43%.
#
# Epoch 91, train_loss is 0.2675, accuracy is 95.92%.
# Test_loss is 1.0914, accuracy is 79.17%.
#
# Epoch 92, train_loss is 0.2410, accuracy is 97.96%.
# Test_loss is 1.0997, accuracy is 79.10%.
#
# Epoch 93, train_loss is 0.2345, accuracy is 97.45%.
# Test_loss is 1.0937, accuracy is 79.62%.
#
# Epoch 94, train_loss is 0.2420, accuracy is 97.96%.
# Test_loss is 1.0745, accuracy is 79.65%.
#
# Epoch 95, train_loss is 0.2323, accuracy is 96.94%.
# Test_loss is 1.0782, accuracy is 79.43%.
#
# Epoch 96, train_loss is 0.3106, accuracy is 94.90%.
# Test_loss is 1.0921, accuracy is 79.41%.
#
# Epoch 97, train_loss is 0.2042, accuracy is 100.00%.
# Test_loss is 1.0956, accuracy is 79.09%.
#
# Epoch 98, train_loss is 0.2089, accuracy is 98.98%.
# Test_loss is 1.0829, accuracy is 79.46%.
#
# Epoch 99, train_loss is 0.2930, accuracy is 96.43%.
# Test_loss is 1.0614, accuracy is 79.74%.
#
# Epoch 100, train_loss is 0.2445, accuracy is 97.96%.
# Test_loss is 1.0677, accuracy is 79.97%.
#
# Training completed.

# %% [markdown]
# ## tensorboard 显示
# - **界面**
#
# > ![](https://github.com/jswanglp/MyML/blob/master/resources/tensorboard.PNG?raw=true)
#
# - **网络图**
#
# > ![](https://github.com/jswanglp/MyML/blob/master/resources/graph_CNN.PNG?raw=true)
#
# - **部分输入图像**
#
# > ![](https://github.com/jswanglp/MyML/blob/master/resources/input_images.PNG?raw=true)
#
# - **训练集、测试集正确率和 loss**
#
# > ![](https://github.com/jswanglp/MyML/blob/master/resources/training_testing_accuracy.PNG?raw=true)
#
# > ![](https://github.com/jswanglp/MyML/blob/master/resources/training_testing_loss.PNG?raw=true)
